# %%
import cv2
import matplotlib.pyplot as plt

# %%
read_image=cv2.imread('image_01.png',0)
read_image1=cv2.imread('image_02.png',0)
group=cv2.imread('image_03.png',0)

# %%
plt.imshow(read_image,cmap="gray")
plt.title("Without glass")
plt.axis('on')
plt.show()

# %%
plt.imshow(read_image1,cmap="gray")
plt.title("with glass")
plt.axis('on')
plt.show()

# %%
plt.imshow(group,cmap="gray")
plt.title("Group photo")
plt.axis('on')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(131)
plt.imshow(cv2.resize(read_image,(1000,1000)),cmap="gray")
plt.title("without glass")
plt.subplot(132)
plt.imshow(cv2.resize(read_image1,(1000,1000)),cmap="gray")
plt.title("with glass")
plt.subplot(133)
plt.imshow(cv2.resize(group,(1000,1000)),cmap="gray")
plt.title("Group photo")
# Out:
# Text(0.5, 1.0, 'Group photo')

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    face_img=img.copy()
    face_rects=face_cascade.detectMultiScale(face_img)
    for(x,y,w,h) in face_rects:
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
        plt.imshow(face_img,cmap="grey")
    return face_img

# %%
res = detect_face(read_image)

# %%
res = detect_face(read_image1)

# %%
res = detect_face(group)

# %%
eye_cascade=cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
def detect_eye(img):
    face_img=img.copy()
    eye_rects=eye_cascade.detectMultiScale(face_img)
    for(x,y,w,h) in eye_rects:
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
        plt.imshow(face_img,cmap="grey")
    return face_img

# %%
result=detect_eye(read_image)

# %%
result=detect_eye(read_image1)

# %%
result=detect_eye(group)

# %%
cap=cv2.VideoCapture(0)
plt.ion()
fig,ax=plt.subplots()
ret,frame=cap.read(0)
frame=detect_face(frame)
im=ax.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
plt.title('Video Face Detection')
while True:
    ret,frame =cmap.read(0)
    frame=detect_face(frame)
    im.set_data(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
    plt.pause(0.10)

cap.release()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 9
#       7 plt.title('Video Face Detection')
#       8 while True:
# ----> 9     ret,frame =cmap.read(0)
#      10     frame=detect_face(frame)
#      11     im.set_data(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
#
# NameError: name 'cmap' is not defined
